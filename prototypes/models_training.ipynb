# %%
import numpy as np
import pandas as pd
import pprint as pp

from torch_nn_model import (
    preprocess_dataframe,
    create_vocab_for_column,
    get_best_available_device,
    cross_val_train_nn_model,
    extract_embeddings,
    NNHyperparams,
)

from torch_nn_model_io import (
    save_model_with_metadata,
    load_debrim_model_from_version,
    load_debrim_embedder_from_version,
    load_debrim_metadata,
)

from ml_model import MLHyperparams, train_classical_models_cv
from ml_model_io import (
    save_ml_models_with_metadata,
    load_ml_models_from_version,
    load_ml_model_from_version,
    load_ml_version_metadata,
    load_ml_model_metadata,
)

# %%
# Define feature columns and load data

FEATURE_NAMES = [
    "hw_features",
    "req_permissions",
    "app_components",
    "intents",
    "api_calls",
    "used_permissions",
    "sus_api_calls",
    "urls",
]

SCALAR_COLS = []

# Load data
df = pd.read_csv("test_1k.csv")
df = df.replace(np.nan, "")
df = df.drop(columns=["family"])

df = preprocess_dataframe(df, FEATURE_NAMES)

# Create vocabulary dictionary
vocab_dict = {col: create_vocab_for_column(df, col) for col in FEATURE_NAMES}

print(vocab_dict["hw_features"].get_itos())
display(df)

# Get the best available device
device = get_best_available_device()
# Out:
# ['<PAD>', '<UNK>', '<EMPTY>', 'android.hardware.touchscreen', 'android.hardware.screen.portrait', 'android.hardware.location', 'android.hardware.location.network', 'android.hardware.location.gps', 'android.hardware.telephony', 'android.hardware.wifi', 'android.hardware.screen.landscape', 'android.hardware.camera', 'android.hardware.camera.autofocus', 'android.hardware.microphone', 'android.hardware.bluetooth', 'android.software.live_wallpaper', 'android.hardware.touchscreen.multitouch', 'android.hardware.sensor.accelerometer', 'ACCESS_COARSE_LOCATION', 'READ_SMS', 'RECEIVE_SMS', 'android.hardware.camera.flash', 'android.hardware.nfc', 'android.hardware.sensor.compass']
#                                                 sha256  \
# 0    00002d74a9faa53f5199c910b652ef09d3a7f6bd42b693...
# 1    000068216bdb459df847bfdd67dd11069c3c50166db1ea...
# 2    0000764713b286cfe7e8e76c7038c92312977712d9c5a8...
# 3    0000962c2c34de1ca0c329b18be7847459da2d9d14b6b2...
# 4    000167f1ff061ea91440c40659c11c2af160342fd2e493...
# ..                                                 ...
# 995  01e78d647cabf702bdbbb3af46ab70f2cbb407dfe6c6f8...
# 996  01e7a30caff13ed959ec74a26ec27564dea94389200ed9...
# 997  01e7a6ea485da0acbe7ac6f7c1dbb20df27faa3a06130f...
# 998  01e86ce55b5175a75ed513d452c5a7169a56d013d822f1...
# 999  01e8ac3c858b20f7ec6b641380814e29d6b000dce822cb...
#
#                                            hw_features  \
# 0    [android.hardware.touchscreen, android.hardwar...
# 1                       [android.hardware.touchscreen]
# 2    [android.hardware.touchscreen, android.hardwar...
# 3    [android.hardware.touchscreen, android.hardwar...
# 4    [android.hardware.touchscreen, android.hardwar...
# ..                                                 ...
# 995  [android.hardware.touchscreen, android.hardwar...
# 996                     [android.hardware.touchscreen]
# 997  [android.hardware.touchscreen, android.hardwar...
# 998  [android.hardware.touchscreen, android.hardwar...
# 999  [android.hardware.touchscreen, android.hardwar...
#
#                                        req_permissions  \
# 0    [android.permission.READ_PHONE_STATE, android....
# 1    [android.permission.WRITE_EXTERNAL_STORAGE, an...
# 2    [android.permission.ACCESS_FINE_LOCATION, andr...
# 3                        [android.permission.INTERNET]
# 4    [android.permission.INTERNET, android.permissi...
# ..                                                 ...
# 995  [android.permission.INTERNET, android.permissi...
# 996        [android.permission.WRITE_EXTERNAL_STORAGE]
# 997  [android.permission.INTERNET, android.permissi...
# 998  [android.permission.INTERNET, com.android.vend...
# 999  [android.permission.ACCESS_FINE_LOCATION, andr...
#
#                                         app_components  \
# 0    [.GameBootReceiver, .GameService, GameAlertDia...
# 1    [paklena.batterydiviner.Settings, paklena.batt...
# 2    [BootReceiver, ru.alpha.AlphaReceiver, ru.alph...
# 3                                      [.index, index]
# 4    [NokyART, .NokyArtWidget$UpdateService, .NokyA...
# ..                                                 ...
# 995                                   [.EmotionSensor]
# 996                                            [.main]
# 997                                    [.zaragoza_872]
# 998                                    [.MainActivity]
# 999                                          [.Direct]
#
#                                                intents  \
# 0    [android.intent.action.BOOT_COMPLETED, android...
# 1    [android.intent.category.HOME, android.intent....
# 2    [android.intent.category.HOME, android.intent....
# 3    [android.intent.action.MAIN, android.intent.ca...
# 4    [android.intent.action.MAIN, android.intent.ca...
# ..                                                 ...
# 995  [android.intent.action.MAIN, android.intent.ca...
# 996  [android.intent.action.MAIN, android.intent.ca...
# 997  [android.intent.action.MAIN, android.intent.ca...
# 998  [android.intent.action.MAIN, android.intent.ca...
# 999  [android.intent.action.MAIN, android.intent.ca...
#
#                                              api_calls  \
# 0    [java/net/HttpURLConnection, android/content/C...
# 1    [android/content/Context;->startService, andro...
# 2    [android/net/ConnectivityManager;->getActiveNe...
# 3                             [android/webkit/WebView]
# 4    [android/net/ConnectivityManager;->getNetworkI...
# ..                                                 ...
# 995  [android/net/ConnectivityManager;->getActiveNe...
# 996  [android/content/ContentResolver;->openInputSt...
# 997  [android/telephony/TelephonyManager;->getDevic...
# 998  [android/app/Activity;->startActivity, android...
# 999  [android/telephony/TelephonyManager;->getDevic...
#
#                                       used_permissions  \
# 0    [android.permission.INTERNET, android.permissi...
# 1                         [android.permission.VIBRATE]
# 2    [android.permission.INTERNET, android.permissi...
# 3                        [android.permission.INTERNET]
# 4    [android.permission.INTERNET, android.permissi...
# ..                                                 ...
# 995  [android.permission.ACCESS_NETWORK_STATE, andr...
# 996  [android.permission.INTERNET, android.permissi...
# 997  [android.permission.ACCESS_FINE_LOCATION, andr...
# 998  [android.permission.READ_CONTACTS, android.per...
# 999  [android.permission.GET_ACCOUNTS, android.perm...
#
#                                          sus_api_calls  \
# 0    [Read/Write External Storage, getPackageInfo, ...
# 1      [Read/Write External Storage, getSystemService]
# 2    [getDeviceId, Read/Write External Storage, Obf...
# 3                                   [getSystemService]
# 4                                   [getSystemService]
# ..                                                 ...
# 995  [getPackageInfo, getSystemService, Cipher(AES/...
# 996    [Read/Write External Storage, getSystemService]
# 997  [getDeviceId, printStackTrace, Read/Write Exte...
# 998  [printStackTrace, getPackageInfo, getSystemSer...
# 999  [getDeviceId, printStackTrace, getSystemServic...
#
#                                                   urls  malware
# 0    [http://client.go360days.com/client.php?action...        1
# 1                                                   []        0
# 2    [http://m-001.net/i/, m-001.net, http://m-001....        1
# 3                                                   []        0
# 4    [http://nokyart.n97.fr/Application/android/ind...        0
# ..                                                 ...      ...
# 995  [http://schemas.android.com/apk/lib/com.google...        0
# 996                                                 []        0
# 997                                                 []        0
# 998  [http://market.android.com/details?id%3D, http...        0
# 999                                                 []        0
#
# [1000 rows x 10 columns]
# Using CUDA device: NVIDIA GeForce RTX 4070 SUPER
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\david\miniconda3\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "C:\Users\david\miniconda3\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "C:\Users\david\miniconda3\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3098, in run_cell
#     result = self._run_cell(
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3153, in _run_cell
#     result = runner(coro)
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3365, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3610, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\.venv\Lib\site-packages\IPython\core\interactiveshell.py", line 3670, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\david\AppData\Local\Temp\ipykernel_24320\222278745.py", line 30, in <module>
#     device = get_best_available_device()
#   File "c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\torch_nn_model.py", line 533, in get_best_available_device
#     device = torch.device("cuda")
# c:\Users\david\Desktop\Clase\TFG\tfg_24_25\prototypes\torch_nn_model.py:533: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:84.)
#   device = torch.device("cuda")

# %%
# Configure hyperparameters
nn_hyperparams = NNHyperparams(
    batch_size=64,
    learning_rate=1e-3,
    epochs=10,
    early_stopping=True,
    patience=5,
    optimizer="adam",
    weight_decay=1e-5,
    embedding_dim=128,
    hidden_dims=[128, 64],
    dropout=0.5,
    seq_pooling="mean",
    n_classes=2,
    label_col="malware",
)

# Train with cross-validation
nn_results, best_nn_model = cross_val_train_nn_model(
    df=df,
    vocab_dict=vocab_dict,
    scalar_cols=SCALAR_COLS,
    hyperparams=nn_hyperparams,
    n_folds=2,
    n_repetitions=5,
    scoring_metric="recall",
    device=device,
    random_seed=42,
)
# Out:
# Using device: cuda
# Using recall as the primary scoring metric
#
# === Repetition 1/5, Fold 1/2 ===
# Training set class distribution: {0: 474, 1: 26}
# Validation set class distribution: {0: 473, 1: 27}
# Epoch 1: Train Loss = 0.5966, Val Loss = 0.4966, recall = 0.9500
# Epoch 2: Train Loss = 0.4531, Val Loss = 0.4250, recall = 0.9520
# Epoch 3: Train Loss = 0.2767, Val Loss = 0.3284, recall = 0.9120
# Epoch 4: Train Loss = 0.2890, Val Loss = 0.3664, recall = 0.9360
# Epoch 5: Train Loss = 0.1380, Val Loss = 0.3363, recall = 0.9400
# Epoch 6: Train Loss = 0.1860, Val Loss = 0.3036, recall = 0.9080
# Epoch 7: Train Loss = 0.1193, Val Loss = 0.3264, recall = 0.9380
# Epoch 8: Train Loss = 0.0989, Val Loss = 0.3796, recall = 0.9480
# Epoch 9: Train Loss = 0.0743, Val Loss = 0.4590, recall = 0.9520
# Epoch 10: Train Loss = 0.0539, Val Loss = 0.4453, recall = 0.9460
#   * New best model: RECALL=0.9460
# Fold 1 results: F1=0.9514, Accuracy=0.9460, Precision=0.9606, Recall=0.9460, PR-AUC=0.7248, ROC-AUC=0.9558
# Training time: 1.49 seconds
#
# === Repetition 1/5, Fold 2/2 ===
# Training set class distribution: {0: 473, 1: 27}
# Validation set class distribution: {0: 474, 1: 26}
# Epoch 1: Train Loss = 0.7099, Val Loss = 0.5734, recall = 0.9560
# Epoch 2: Train Loss = 0.5833, Val Loss = 0.4984, recall = 0.9660
# Epoch 3: Train Loss = 0.4929, Val Loss = 0.3936, recall = 0.9520
# Epoch 4: Train Loss = 0.3833, Val Loss = 0.3245, recall = 0.9520
# Epoch 5: Train Loss = 0.3328, Val Loss = 0.2609, recall = 0.9560
# Epoch 6: Train Loss = 0.2673, Val Loss = 0.2157, recall = 0.9320
# Epoch 7: Train Loss = 0.1989, Val Loss = 0.2120, recall = 0.9560
# Epoch 8: Train Loss = 0.1591, Val Loss = 0.2219, recall = 0.9600
# Epoch 9: Train Loss = 0.1126, Val Loss = 0.2501, recall = 0.9600
# Epoch 10: Train Loss = 0.1202, Val Loss = 0.2486, recall = 0.9580
#   * New best model: RECALL=0.9580
# Fold 2 results: F1=0.9624, Accuracy=0.9580, Precision=0.9710, Recall=0.9580, PR-AUC=0.7913, ROC-AUC=0.9693
# Training time: 1.33 seconds
#
# === Repetition 2/5, Fold 1/2 ===
# Training set class distribution: {0: 474, 1: 26}
# Validation set class distribution: {0: 473, 1: 27}
# Epoch 1: Train Loss = 0.6570, Val Loss = 0.5839, recall = 0.9560
# Epoch 2: Train Loss = 0.4893, Val Loss = 0.4600, recall = 0.9480
# Epoch 3: Train Loss = 0.3426, Val Loss = 0.4411, recall = 0.9480
# Epoch 4: Train Loss = 0.1962, Val Loss = 0.3511, recall = 0.9460
# Epoch 5: Train Loss = 0.1453, Val Loss = 0.3913, recall = 0.9420
# Epoch 6: Train Loss = 0.1262, Val Loss = 0.5133, recall = 0.9520
# Epoch 7: Train Loss = 0.0661, Val Loss = 0.5920, recall = 0.9560
# Epoch 8: Train Loss = 0.0648, Val Loss = 0.7006, recall = 0.9580
# Epoch 9: Train Loss = 0.0404, Val Loss = 0.8101, recall = 0.9580
# Early stopping after 9 epochs
# Fold 3 results: F1=0.9576, Accuracy=0.9580, Precision=0.9573, Recall=0.9580, PR-AUC=0.7007, ROC-AUC=0.9464
# Training time: 1.15 seconds
#
# === Repetition 2/5, Fold 2/2 ===
# Training set class distribution: {0: 473, 1: 27}
# Validation set class distribution: {0: 474, 1: 26}
# Epoch 1: Train Loss = 0.6689, Val Loss = 0.5706, recall = 0.9600
# Epoch 2: Train Loss = 0.5953, Val Loss = 0.4446, recall = 0.9680
# Epoch 3: Train Loss = 0.4835, Val Loss = 0.3352, recall = 0.9420
# Epoch 4: Train Loss = 0.3949, Val Loss = 0.2531, recall = 0.9300
# Epoch 5: Train Loss = 0.2779, Val Loss = 0.2004, recall = 0.9200
# Epoch 6: Train Loss = 0.2224, Val Loss = 0.1745, recall = 0.9120
# Epoch 7: Train Loss = 0.1614, Val Loss = 0.1448, recall = 0.9380
# Epoch 8: Train Loss = 0.1939, Val Loss = 0.1361, recall = 0.9380
# Epoch 9: Train Loss = 0.1725, Val Loss = 0.1321, recall = 0.9380
# Epoch 10: Train Loss = 0.1226, Val Loss = 0.1263, recall = 0.9480
# Fold 4 results: F1=0.9555, Accuracy=0.9480, Precision=0.9719, Recall=0.9480, PR-AUC=0.8166, ROC-AUC=0.9895
# Training time: 1.30 seconds
#
# === Repetition 3/5, Fold 1/2 ===
# Training set class distribution: {0: 474, 1: 26}
# Validation set class distribution: {0: 473, 1: 27}
# Epoch 1: Train Loss = 0.6426, Val Loss = 0.5487, recall = 0.9780
# Epoch 2: Train Loss = 0.5270, Val Loss = 0.4249, recall = 0.9360
# Epoch 3: Train Loss = 0.4420, Val Loss = 0.3250, recall = 0.8680
# Epoch 4: Train Loss = 0.3282, Val Loss = 0.2768, recall = 0.9480
# Epoch 5: Train Loss = 0.2535, Val Loss = 0.2423, recall = 0.9400
# Epoch 6: Train Loss = 0.1728, Val Loss = 0.2374, recall = 0.9480
# Epoch 7: Train Loss = 0.1861, Val Loss = 0.2488, recall = 0.9540
# Epoch 8: Train Loss = 0.1472, Val Loss = 0.2511, recall = 0.9440
# Epoch 9: Train Loss = 0.0913, Val Loss = 0.4238, recall = 0.9740
# Epoch 10: Train Loss = 0.0964, Val Loss = 0.3923, recall = 0.9700
#   * New best model: RECALL=0.9700
# Fold 5 results: F1=0.9712, Accuracy=0.9700, Precision=0.9730, Recall=0.9700, PR-AUC=0.8234, ROC-AUC=0.9661
# Training time: 1.34 seconds
#
# === Repetition 3/5, Fold 2/2 ===
# Training set class distribution: {0: 473, 1: 27}
# Validation set class distribution: {0: 474, 1: 26}
# Epoch 1: Train Loss = 0.6291, Val Loss = 0.5530, recall = 0.9640
# Epoch 2: Train Loss = 0.4867, Val Loss = 0.4241, recall = 0.9460
# Epoch 3: Train Loss = 0.4003, Val Loss = 0.3157, recall = 0.9360
# Epoch 4: Train Loss = 0.2670, Val Loss = 0.2479, recall = 0.9160
# Epoch 5: Train Loss = 0.1935, Val Loss = 0.2543, recall = 0.9380
# Epoch 6: Train Loss = 0.1507, Val Loss = 0.3158, recall = 0.9440
# Epoch 7: Train Loss = 0.1500, Val Loss = 0.2318, recall = 0.9360
# Epoch 8: Train Loss = 0.1571, Val Loss = 0.2421, recall = 0.9380
# Epoch 9: Train Loss = 0.0808, Val Loss = 0.3294, recall = 0.9500
# Epoch 10: Train Loss = 0.0755, Val Loss = 0.3170, recall = 0.9420
# Fold 6 results: F1=0.9486, Accuracy=0.9420, Precision=0.9597, Recall=0.9420, PR-AUC=0.7204, ROC-AUC=0.9610
# Training time: 1.48 seconds
#
# === Repetition 4/5, Fold 1/2 ===
# Training set class distribution: {0: 474, 1: 26}
# Validation set class distribution: {0: 473, 1: 27}
# Epoch 1: Train Loss = 0.6608, Val Loss = 0.5774, recall = 0.9460
# Epoch 2: Train Loss = 0.5730, Val Loss = 0.4859, recall = 0.9620
# Epoch 3: Train Loss = 0.4767, Val Loss = 0.3766, recall = 0.9700
# Epoch 4: Train Loss = 0.3746, Val Loss = 0.2841, recall = 0.9580
# Epoch 5: Train Loss = 0.3330, Val Loss = 0.2058, recall = 0.9460
# Epoch 6: Train Loss = 0.2723, Val Loss = 0.1678, recall = 0.9360
# Epoch 7: Train Loss = 0.1855, Val Loss = 0.1683, recall = 0.9620
# Epoch 8: Train Loss = 0.1876, Val Loss = 0.1503, recall = 0.9580
# Epoch 9: Train Loss = 0.1235, Val Loss = 0.1560, recall = 0.9560
# Epoch 10: Train Loss = 0.1294, Val Loss = 0.2082, recall = 0.9720
#   * New best model: RECALL=0.9720
# Fold 7 results: F1=0.9733, Accuracy=0.9720, Precision=0.9755, Recall=0.9720, PR-AUC=0.8973, ROC-AUC=0.9874
# Training time: 1.41 seconds
#
# === Repetition 4/5, Fold 2/2 ===
# Training set class distribution: {0: 473, 1: 27}
# Validation set class distribution: {0: 474, 1: 26}
# Epoch 1: Train Loss = 0.6558, Val Loss = 0.5522, recall = 0.9620
# Epoch 2: Train Loss = 0.5038, Val Loss = 0.4357, recall = 0.9580
# Epoch 3: Train Loss = 0.3915, Val Loss = 0.3488, recall = 0.9440
# Epoch 4: Train Loss = 0.2672, Val Loss = 0.2977, recall = 0.9180
# Epoch 5: Train Loss = 0.2265, Val Loss = 0.3063, recall = 0.9480
# Epoch 6: Train Loss = 0.1232, Val Loss = 0.3083, recall = 0.9480
# Epoch 7: Train Loss = 0.1308, Val Loss = 0.3344, recall = 0.9480
# Epoch 8: Train Loss = 0.0831, Val Loss = 0.3701, recall = 0.9500
# Epoch 9: Train Loss = 0.0801, Val Loss = 0.3834, recall = 0.9500
# Early stopping after 9 epochs
# Fold 8 results: F1=0.9562, Accuracy=0.9500, Precision=0.9683, Recall=0.9500, PR-AUC=0.6895, ROC-AUC=0.9523
# Training time: 1.31 seconds
#
# === Repetition 5/5, Fold 1/2 ===
# Training set class distribution: {0: 474, 1: 26}
# Validation set class distribution: {0: 473, 1: 27}
# Epoch 1: Train Loss = 0.6185, Val Loss = 0.5064, recall = 0.9580
# Epoch 2: Train Loss = 0.5077, Val Loss = 0.3792, recall = 0.9300
# Epoch 3: Train Loss = 0.4108, Val Loss = 0.2791, recall = 0.9320
# Epoch 4: Train Loss = 0.2917, Val Loss = 0.2331, recall = 0.9420
# Epoch 5: Train Loss = 0.2173, Val Loss = 0.2093, recall = 0.9140
# Epoch 6: Train Loss = 0.1967, Val Loss = 0.2078, recall = 0.9200
# Epoch 7: Train Loss = 0.1842, Val Loss = 0.2085, recall = 0.9180
# Epoch 8: Train Loss = 0.0951, Val Loss = 0.2334, recall = 0.9480
# Epoch 9: Train Loss = 0.0782, Val Loss = 0.2345, recall = 0.9440
# Epoch 10: Train Loss = 0.1018, Val Loss = 0.2373, recall = 0.9340
# Fold 9 results: F1=0.9440, Accuracy=0.9340, Precision=0.9636, Recall=0.9340, PR-AUC=0.7222, ROC-AUC=0.9728
# Training time: 1.46 seconds
#
# === Repetition 5/5, Fold 2/2 ===
# Training set class distribution: {0: 473, 1: 27}
# Validation set class distribution: {0: 474, 1: 26}
# Epoch 1: Train Loss = 0.7292, Val Loss = 0.5766, recall = 0.9480
# Epoch 2: Train Loss = 0.5590, Val Loss = 0.5157, recall = 0.9620
# Epoch 3: Train Loss = 0.4688, Val Loss = 0.4626, recall = 0.9700
# Epoch 4: Train Loss = 0.3602, Val Loss = 0.4291, recall = 0.9620
# Epoch 5: Train Loss = 0.2883, Val Loss = 0.3641, recall = 0.9440
# Epoch 6: Train Loss = 0.1898, Val Loss = 0.3642, recall = 0.9460
# Epoch 7: Train Loss = 0.1785, Val Loss = 0.3928, recall = 0.9460
# Epoch 8: Train Loss = 0.1139, Val Loss = 0.5163, recall = 0.9640
# Epoch 9: Train Loss = 0.0752, Val Loss = 0.6465, recall = 0.9700
# Epoch 10: Train Loss = 0.0638, Val Loss = 0.7933, recall = 0.9720
# Early stopping after 10 epochs
# Fold 10 results: F1=0.9709, Accuracy=0.9720, Precision=0.9703, Recall=0.9720, PR-AUC=0.7807, ROC-AUC=0.9512
# Training time: 1.46 seconds
#
# === Overall Results ===
# Mean accuracy: 0.9550 ± 0.0126
# Mean precision: 0.9671 ± 0.0060
# Mean recall: 0.9550 ± 0.0126
# Mean f1: 0.9591 ± 0.0096
# Mean pr_auc: 0.7667 ± 0.0630
# Mean roc_auc: 0.9652 ± 0.0141
# Mean model_size: 5972.9258 ± 0.0000
# Mean training_time: 1.3724 ± 0.1012
# Best model from fold 7 with recall=0.9720

# %%
# Save the model and components
save_paths = save_model_with_metadata(
    model=best_nn_model,
    vocab_dict=vocab_dict,
    hyperparams=nn_hyperparams,
    results=nn_results,
)

# Load the latest model version
model, vocab_dict, metadata = load_debrim_model_from_version()

# Load a specific model version
model, vocab_dict, metadata = load_debrim_model_from_version()

# Load just the embedder from the latest version
embedder, vocab_dict, metadata = load_debrim_embedder_from_version()

# Load just metadata to check performance metrics
metadata = load_debrim_metadata()
print(f"F1 Score: {metadata['all_metrics'].get('mean_f1', 'N/A')}")
# Out:
# Model and artifacts saved to ./model_artifacts/nn_models\20250520_001800
# Using CUDA device: NVIDIA GeForce RTX 4070 SUPER
# Loading latest model version: 20250520_001800
# Model loaded from ./model_artifacts/nn_models\20250520_001800
# Using CUDA device: NVIDIA GeForce RTX 4070 SUPER
# Loading latest model version: 20250520_001800
# Model loaded from ./model_artifacts/nn_models\20250520_001800
# Using CUDA device: NVIDIA GeForce RTX 4070 SUPER
# Loading latest model version: 20250520_001800
# Embedder loaded from ./model_artifacts/nn_models\20250520_001800
# Loading latest model version: 20250520_001800
# F1 Score: 0.959117854641144

# %%
# Train classical ML models on embeddings

X, y = extract_embeddings(
    df=df,
    vocab_dict=vocab_dict,
    scalar_cols=SCALAR_COLS,
    model=embedder,
    device=device,
)


ml_hyperarams_dict = {
    "RandomForest": MLHyperparams(
        model_type="random_forest",
        n_estimators=100,
        max_depth=10,
        min_samples_split=2,
        min_samples_leaf=1,
        random_state=42,
    ),
    "XGBoost": MLHyperparams(
        model_type="xgboost",
        n_estimators=100,
        max_depth=10,
        learning_rate=0.1,
        random_state=42,
    ),
    "KNeighbors": MLHyperparams(
        model_type="knn",
        n_neighbors=5,
        weights="uniform",
    ),
    "SVM": MLHyperparams(
        model_type="svm",
        kernel="linear",
        C=1.0,
        random_state=42,
    ),
    "LogisticRegression": MLHyperparams(
        model_type="logistic_regression",
        C=1.0,
        solver="lbfgs",
        random_state=42,
    ),
}

# Train classical models with cross-validation
ml_results, ml_best_models = train_classical_models_cv(
    X=X,
    y=y,
    hyperparams_dict=ml_hyperarams_dict,
    n_folds=2,
    n_repetitions=5,
    scoring_metric="recall",
    random_state=42,
)
# Out:
# Training 5 models with 5 x 2-fold cross-validation...
#
# === Repetition 1/5, Fold 1/2 ===
# Class distribution:
#   Class 0: 474 train, 473 test
#   Class 1: 26 train, 27 test
# Training RandomForest...
#   RandomForest: F1=0.9375, Accuracy=0.9540, Size=201.6KB, Time=0.21s
#   ★ New best RandomForest model: recall=0.9540
# Training XGBoost...
#   XGBoost: F1=0.9470, Accuracy=0.9540, Size=87.7KB, Time=0.41s
#   ★ New best XGBoost model: recall=0.9540
# Training KNeighbors...
#   KNeighbors: F1=0.9516, Accuracy=0.9580, Size=4004.6KB, Time=0.00s
#   ★ New best KNeighbors model: recall=0.9580
# Training SVM...
#   SVM: F1=0.9756, Accuracy=0.9760, Size=586.7KB, Time=0.02s
#   ★ New best SVM model: recall=0.9760
# Training LogisticRegression...
#   LogisticRegression: F1=0.9716, Accuracy=0.9700, Size=8.7KB, Time=0.01s
#   ★ New best LogisticRegression model: recall=0.9700
#
# === Repetition 1/5, Fold 2/2 ===
# Class distribution:
#   Class 0: 473 train, 474 test
#   Class 1: 27 train, 26 test
# Training RandomForest...
#   RandomForest: F1=0.9594, Accuracy=0.9660, Size=244.4KB, Time=0.24s
#   ★ New best RandomForest model: recall=0.9660
# Training XGBoost...
#   XGBoost: F1=0.9680, Accuracy=0.9720, Size=90.4KB, Time=0.40s
#   ★ New best XGBoost model: recall=0.9720
# Training KNeighbors...
#   KNeighbors: F1=0.9514, Accuracy=0.9600, Size=4004.6KB, Time=0.00s
#   ★ New best KNeighbors model: recall=0.9600
# Training SVM...
#   SVM: F1=0.9792, Accuracy=0.9800, Size=618.8KB, Time=0.02s
#   ★ New best SVM model: recall=0.9800
# Training LogisticRegression...
#   LogisticRegression: F1=0.9800, Accuracy=0.9800, Size=8.7KB, Time=0.01s
#   ★ New best LogisticRegression model: recall=0.9800
#
# === Repetition 2/5, Fold 1/2 ===
# Class distribution:
#   Class 0: 474 train, 473 test
#   Class 1: 26 train, 27 test
# Training RandomForest...
#   RandomForest: F1=0.9521, Accuracy=0.9620, Size=203.9KB, Time=0.21s
# Training XGBoost...
#   XGBoost: F1=0.9553, Accuracy=0.9640, Size=87.3KB, Time=0.38s
# Training KNeighbors...
#   KNeighbors: F1=0.9597, Accuracy=0.9660, Size=4004.6KB, Time=0.00s
#   ★ New best KNeighbors model: recall=0.9660
# Training SVM...
#   SVM: F1=0.9671, Accuracy=0.9700, Size=522.5KB, Time=0.02s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9692, Accuracy=0.9700, Size=8.7KB, Time=0.01s
#
# === Repetition 2/5, Fold 2/2 ===
# Class distribution:
#   Class 0: 473 train, 474 test
#   Class 1: 27 train, 26 test
# Training RandomForest...
#   RandomForest: F1=0.9563, Accuracy=0.9640, Size=263.7KB, Time=0.24s
# Training XGBoost...
#   XGBoost: F1=0.9815, Accuracy=0.9820, Size=91.1KB, Time=0.42s
#   ★ New best XGBoost model: recall=0.9820
# Training KNeighbors...
#   KNeighbors: F1=0.9543, Accuracy=0.9600, Size=4004.6KB, Time=0.00s
# Training SVM...
#   SVM: F1=0.9795, Accuracy=0.9780, Size=707.0KB, Time=0.03s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9764, Accuracy=0.9740, Size=8.7KB, Time=0.01s
#
# === Repetition 3/5, Fold 1/2 ===
# Class distribution:
#   Class 0: 474 train, 473 test
#   Class 1: 26 train, 27 test
# Training RandomForest...
#   RandomForest: F1=0.9521, Accuracy=0.9620, Size=213.2KB, Time=0.22s
# Training XGBoost...
#   XGBoost: F1=0.9697, Accuracy=0.9720, Size=89.5KB, Time=0.45s
# Training KNeighbors...
#   KNeighbors: F1=0.9608, Accuracy=0.9660, Size=4004.6KB, Time=0.00s
# Training SVM...
#   SVM: F1=0.9788, Accuracy=0.9800, Size=650.9KB, Time=0.02s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9899, Accuracy=0.9900, Size=8.7KB, Time=0.02s
#   ★ New best LogisticRegression model: recall=0.9900
#
# === Repetition 3/5, Fold 2/2 ===
# Class distribution:
#   Class 0: 473 train, 474 test
#   Class 1: 27 train, 26 test
# Training RandomForest...
#   RandomForest: F1=0.9563, Accuracy=0.9640, Size=242.4KB, Time=0.23s
# Training XGBoost...
#   XGBoost: F1=0.9644, Accuracy=0.9680, Size=89.7KB, Time=0.39s
# Training KNeighbors...
#   KNeighbors: F1=0.9609, Accuracy=0.9640, Size=4004.6KB, Time=0.00s
# Training SVM...
#   SVM: F1=0.9657, Accuracy=0.9660, Size=626.8KB, Time=0.02s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9636, Accuracy=0.9620, Size=8.7KB, Time=0.01s
#
# === Repetition 4/5, Fold 1/2 ===
# Class distribution:
#   Class 0: 474 train, 473 test
#   Class 1: 26 train, 27 test
# Training RandomForest...
#   RandomForest: F1=0.9585, Accuracy=0.9660, Size=219.3KB, Time=0.22s
# Training XGBoost...
#   XGBoost: F1=0.9701, Accuracy=0.9740, Size=90.4KB, Time=0.40s
# Training KNeighbors...
#   KNeighbors: F1=0.9645, Accuracy=0.9700, Size=4004.6KB, Time=0.00s
#   ★ New best KNeighbors model: recall=0.9700
# Training SVM...
#   SVM: F1=0.9715, Accuracy=0.9740, Size=562.6KB, Time=0.02s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9811, Accuracy=0.9820, Size=8.7KB, Time=0.01s
#
# === Repetition 4/5, Fold 2/2 ===
# Class distribution:
#   Class 0: 473 train, 474 test
#   Class 1: 27 train, 26 test
# Training RandomForest...
#   RandomForest: F1=0.9594, Accuracy=0.9660, Size=228.0KB, Time=0.22s
# Training XGBoost...
#   XGBoost: F1=0.9635, Accuracy=0.9660, Size=88.1KB, Time=0.39s
# Training KNeighbors...
#   KNeighbors: F1=0.9481, Accuracy=0.9540, Size=4004.6KB, Time=0.00s
# Training SVM...
#   SVM: F1=0.9603, Accuracy=0.9580, Size=642.8KB, Time=0.02s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9547, Accuracy=0.9500, Size=8.7KB, Time=0.02s
#
# === Repetition 5/5, Fold 1/2 ===
# Class distribution:
#   Class 0: 474 train, 473 test
#   Class 1: 26 train, 27 test
# Training RandomForest...
#   RandomForest: F1=0.9654, Accuracy=0.9700, Size=223.2KB, Time=0.22s
#   ★ New best RandomForest model: recall=0.9700
# Training XGBoost...
#   XGBoost: F1=0.9654, Accuracy=0.9680, Size=90.8KB, Time=0.40s
# Training KNeighbors...
#   KNeighbors: F1=0.9593, Accuracy=0.9620, Size=4004.6KB, Time=0.00s
# Training SVM...
#   SVM: F1=0.9592, Accuracy=0.9560, Size=610.8KB, Time=0.02s
# Training LogisticRegression...
#   LogisticRegression: F1=0.9602, Accuracy=0.9560, Size=8.7KB, Time=0.02s
#
# === Repetition 5/5, Fold 2/2 ===
# Class distribution:
#   Class 0: 473 train, 474 test
#   Class 1: 27 train, 26 test
# Training RandomForest...
#   RandomForest: F1=0.9479, Accuracy=0.9600, Size=242.7KB, Time=0.23s
# Training XGBoost...
#   XGBoost: F1=0.9670, Accuracy=0.9720, Size=89.1KB, Time=0.37s
# Training KNeighbors...
#   KNeighbors: F1=0.9580, Accuracy=0.9660, Size=4004.6KB, Time=0.00s
# Training SVM...
#   SVM: F1=0.9802, Accuracy=0.9820, Size=538.6KB, Time=0.02s
#   ★ New best SVM model: recall=0.9820
# Training LogisticRegression...
#   LogisticRegression: F1=0.9811, Accuracy=0.9820, Size=8.7KB, Time=0.01s
#
# === RandomForest Summary ===
# Mean RECALL: 0.9634 ± 0.0041
# Best RECALL: 0.9700
# Mean Size: 228.2KB
# Mean Training Time: 0.22s
#
# === XGBoost Summary ===
# Mean RECALL: 0.9692 ± 0.0069
# Best RECALL: 0.9820
# Mean Size: 89.4KB
# Mean Training Time: 0.40s
#
# === KNeighbors Summary ===
# Mean RECALL: 0.9626 ± 0.0045
# Best RECALL: 0.9700
# Mean Size: 4004.6KB
# Mean Training Time: 0.00s
#
# === SVM Summary ===
# Mean RECALL: 0.9720 ± 0.0088
# Best RECALL: 0.9820
# Mean Size: 606.7KB
# Mean Training Time: 0.02s
#
# === LogisticRegression Summary ===
# Mean RECALL: 0.9716 ± 0.0120
# Best RECALL: 0.9900
# Mean Size: 8.7KB
# Mean Training Time: 0.01s
#
# Best models saved for each model type.

# %%
ml_saved_paths = save_ml_models_with_metadata(
    models=ml_best_models, results=ml_results, save_dir="./model_artifacts/ml_models"
)

# loaded_ml_models, version_metadata = load_ml_models_from_version()
# Out:
# Saved 5 model(s) to ./model_artifacts/ml_models\20250520_001808
#   - RandomForest
#   - XGBoost
#   - KNeighbors
#   - SVM
#   - LogisticRegression
